# %%
# Python Standard Library
import sys

# Community Modules
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# My Modules
sys.path.insert(0, "../code")
import measure_signal as ms
import dataset_utils as du
import spectral_sparklines as sp

from importlib import reload

RNG = np.random.default_rng(1415)
# Out:
# 2026-03-28 15:17:59.297765: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-28 15:17:59.316002: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-28 15:17:59.321652: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-28 15:17:59.335819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-28 15:18:01.500632: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
