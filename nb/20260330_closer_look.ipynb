# %%
# Python Standard Library
import sys

# Community Modules
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from IPython.display import display, clear_output

# My Modules
sys.path.insert(0, "../code")
import review_spectrum as rs
import measure_signal as ms
# import dataset_utils as du
# import spectral_features as sf

# sys.path.insert(0, "../../ABC-SN/code")
# import abcsn_config
# import abcsn_training
# import data_degrading as dg
# import data_plotting as dplt
# import data_preparation as dp
# import preprocessing

from importlib import reload

# %%
# FILE_DATASET = "../data/forSNR/closer_look.parquet"
# df_dataset = pd.read_parquet(FILE_DATASET)
# df_dataset.loc[40, "Denoising Parameter"] = 30
# df_dataset.to_parquet(FILE_DATASET)

# %%
reload(rs)
reload(ms)
df_dataset = rs.review(i=40, subtype="Ia-norm")
# Out:
# 41 | Ia-norm | sn2008ec at -0.237 (1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /lustre/lrspec/users/2649/miniconda3/envs/fox/lib/python3.9/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 42 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 reload(rs)
#       2 reload(ms)
# ----> 3 df_dataset = rs.review(i=40, subtype="Ia-norm")
#
# File ~/repos/spec_res/nb/../code/review_spectrum.py:60, in review(i, subtype)
#      58 num_spectra, num_wvl = spectra.shape
#      59 ###
# ---> 60 df_meta_i = df_meta.loc[i]
#      61 spec_i = spectra[i]
#      63 identifier = (
# ...

# %%
df_dataset["Denoising Parameter"]
# Out:
# 0     30.0
# 1     40.0
# 2     20.0
# 3     30.0
# 4     30.0
# 5     30.0
# 6     20.0
# 7     30.0
# 8     30.0
# 9     30.0
# 10    30.0
# 11    30.0
# 12    20.0
# 13    30.0
# 14    30.0
# 15    30.0
# 16    30.0
# 17    30.0
# 18    30.0
# 19    20.0
# 20    30.0
# 21    30.0
# 22    30.0
# 23    30.0
# 24    30.0
# 25    30.0
# 26    30.0
# 27    30.0
# 28    30.0
# 29    30.0
# 30    30.0
# 31    30.0
# 32    50.0
# 33    50.0
# 34    30.0
# 35    30.0
# 36    20.0
# 37    30.0
# 38    30.0
# 39    30.0
# 40    30.0
# 41    10.0
# Name: Denoising Parameter, dtype: float64
